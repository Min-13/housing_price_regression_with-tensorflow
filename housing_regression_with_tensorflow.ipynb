# %% [markdown]
# <a href="https://colab.research.google.com/github/Min-13/housing_price_regression_with-tensorflow/blob/main/housing_regression_with_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Regression Task

# %% [markdown]
# 1. Import Required Libraries

# %%
# Import TensorFlow for building and training the neural network
import tensorflow as tf

# Import Keras components for model creation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# For data handling and visualization
import pandas as pd
import numpy as np

# %% [markdown]
# 2. Load and Prepare Dataset

# %%
# Assume X_train, X_test, y_train, y_test are already prepared
# X shape should be (samples, 8 features)
# y shape should be (samples,)

df = pd.read_csv('housing.csv')
print("Training shape:", X_train.shape)
print("Testing shape:", X_test.shape)
# Out:
# Training shape: (16512, 8)
# Testing shape: (4128, 8)

# %%
# Optional: Normalize input features (recommended for neural networks)
X_train = X_train / np.max(X_train)
X_test = X_test / np.max(X_test)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
# Importing the required tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Creating a Scaler
scaler = StandardScaler()

# Separate Features and Target
X, y = df.drop('MedHouseVal', axis=1), df['MedHouseVal']

# Split Into Train and Test Sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Learn mean & std from training data
X_train_scaled = scaler.fit_transform(X_train)

# Applying same scaling to test data
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-5.82710051e-02, -1.00762004e+00,  3.74974804e-01, ...,
#         -1.68208232e-02,  2.90095128e+00, -2.31062112e+00],
#        [-1.87965180e-01,  1.13635758e+00, -1.43401141e-01, ...,
#          5.91541708e-03,  9.96186728e-01, -1.29955751e+00],
#        [-2.74200798e-01, -8.48806888e-01,  8.94954517e-02, ...,
#         -3.97566541e-02, -6.41009264e-02, -5.58778228e-01],
#        ...,
#        [-6.15368821e-01,  6.59918104e-01, -4.92130155e-01, ...,
#         -9.80600490e-02, -1.34489088e+00,  1.21308573e+00],
#        [-1.02935288e-01,  1.37457731e+00,  3.39962650e-02, ...,
#         -1.39284720e-03, -6.83383981e-01,  7.47596046e-01],
#        [-6.75445428e-01, -5.47411024e-02, -9.24741238e-01, ...,
#         -1.46148357e-01, -7.16224749e-01,  5.87427553e-01]])

# %%
X_train_scaled.shape
# Out:
# (16512, 8)

# %% [markdown]
# 3. Training & Evaluating the Model

# %%
# Create a Sequential neural network model
# Sequential means layers are stacked in a linear order
model = Sequential()

# Define the input layer with 8 features
# Each training sample must contain exactly 8 numerical values
model.add(Input((8,)))

# First hidden layer:
# 64 neurons with ReLU activation
# ReLU introduces non-linearity, allowing the model to learn complex patterns
model.add(Dense(64, activation='relu'))

# Second hidden layer:
# Another 64 neurons to increase model capacity and depth
model.add(Dense(64, activation='relu'))

# Output layer:
# 1 neuron because this is a regression task (predicting a continuous value)
# No activation function → linear output for unrestricted numeric predictions
model.add(Dense(1))

# %%
# Updating weights using adaptive gradient decent, minimizing mean squared error & reproting MAE and R Squared Score
model.compile(optimizer='adam', loss='mse', metrics=['mae', 'r2_score'])

# %%
# Training the model
model.fit(X_train_scaled, y_train, epochs=10)
# Out:
# Epoch 1/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7784 - mae: 0.8802 - r2_score: -0.3086
# Epoch 2/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4138 - mae: 0.4592 - r2_score: 0.6888
# Epoch 3/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3719 - mae: 0.4359 - r2_score: 0.7250
# Epoch 4/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3641 - mae: 0.4291 - r2_score: 0.7256
# Epoch 5/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.3275 - mae: 0.4055 - r2_score: 0.7518
# Epoch 6/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.3323 - mae: 0.4026 - r2_score: 0.7530
# Epoch 7/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3189 - mae: 0.3943 - r2_score: 0.7604
# Epoch 8/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3123 - mae: 0.3906 - r2_score: 0.7662
# Epoch 9/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3078 - mae: 0.3848 - r2_score: 0.7652
# Epoch 10/10
# ...

# %%
# Evaluating the model
model.evaluate(X_test_scaled, y_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3270 - mae: 0.3792 - r2_score: 0.7511
# [0.3122923970222473, 0.38281336426734924, 0.7620313763618469]

# %%
df.MedHouseVal.describe()
# Out:
# count    20640.000000
# mean         2.068558
# std          1.153956
# min          0.149990
# 25%          1.196000
# 50%          1.797000
# 75%          2.647250
# max          5.000010
# Name: MedHouseVal, dtype: float64
